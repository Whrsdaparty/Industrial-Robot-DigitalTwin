# %% [markdown]
# # Safety QA
# - [ ] E-stop assumptions safe?
# - [ ] Unexpected motion scenarios considered?
# - [ ] Fault recovery documented?
# - [ ] Safety relay assumptions documented?
# - [ ] Applicable standards identified?
