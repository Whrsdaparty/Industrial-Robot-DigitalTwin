# %% [markdown]
# # Digital Twin QA
# - [ ] Closed-loop twin?
# - [ ] Maintenance integrated?
# - [ ] Statistics integrated?
# - [ ] PLC integrated?
# - [ ] ROS2 integrated?
# - [ ] Historical data retained?
# - [ ] FEM linked?
