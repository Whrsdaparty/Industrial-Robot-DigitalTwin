# %% [markdown]
# # Project Direction QA
#
# Review architecture and scope.
#
# - [ ] Does project scope match intent?
# - [ ] Missing major subsystems?
# - [ ] Missing engineering domains?
# - [ ] Wrong priorities?
# - [ ] Missing stakeholders?
# - [ ] Standards identified?
