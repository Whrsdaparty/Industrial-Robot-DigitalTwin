# %% [markdown]
# # Lifecycle / Commissioning / Acceptance QA
# - [ ] Commissioning steps understandable by technicians?
# - [ ] FAT/SAT criteria measurable?
# - [ ] Evidence requirements defined?
# - [ ] Signoffs included?
# - [ ] Startup sequence complete?
